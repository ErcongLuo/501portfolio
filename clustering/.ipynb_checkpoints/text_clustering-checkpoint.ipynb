# %% [markdown]
# # Text Clustering

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse.construct import random

# <clustering>
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris
# </clustering>

from wordcloud import WordCloud

# %%
path = "/Users/ercongluo/Documents/GU/501/501portfolio/datasets/NewsData/"
DF = pd.read_csv(path + "NewsData_cleanedDF.csv")
DF
# drop_labels = ['000','10', '13', '14', '15', '16', '19', '2017', '2018', '2020', '2021', '2030', '22', '27', '2781', '30', '3779']
# onehot_DF.drop(columns = drop_labels)
# Out:
#     Unnamed: 0        source  \
# 0            0    TechCrunch
# 1            1    TechCrunch
# 2            2     Wiley.com
# 3            3       Reuters
# 4            4       Reuters
# ..         ...           ...
# 95          95  The Guardian
# 96          96     Zacks.com
# 97          97       Reuters
# 98          98       Reuters
# 99          99       Reuters
#
#                                                 title  \
# 0   ev charging solutions become asset liability grid
# 1   hyundai motor group unveils hydrogen strategy ...
# 2   electric vehicles produce substantial toxicity...
# 3   zurich insurance sets climate steps curb c02 e...
# 4   update 1 zurich insurance sets climate steps c...
# ..                                                ...
# 95          deep sea mining cure climate crisis curse
# 96  auto stock roundup aap xpev q2 results f outpu...
# 97  illinois senate passes bill save nuclear plant...
# 98  illinois senate passes bill save nuclear plant...
# 99  update 1 illinois senate passes bill save nucl...
#
#                                           description  \
# 0   although wireless charging still relatively ne...
# 1   hyundai motor group backing hydrogen top energ...
# 2   electric vehicles evs coupled low carbon elect...
# 3   zurich insurance group href https www reuters ...
# 4   zurich insurance group unveiled new climate me...
# ..                                                ...
# 95  trillions metallic nodules sea floor could hel...
# 96  advance auto parts aap xpeng xpev deliver impr...
# 97  illinois senate passed bill early wednesday ai...
# 98  illinois senate passed bill early wednesday ai...
# 99  illinois senate passed bill early wednesday ai...
#
#                                               content
# 0   president joe biden’s plan electric vehicles e...
# 1   hyundai motor group backing hydrogen top energ...
# 2   introduction global society dependent road tra...
# 3   ceo mario greco swiss zurich insurance address...
# 4   reuters staff file photo ceo mario greco swiss...
# ..                                                ...
# 95  display cabinet recently opened broken planet ...
# 96  august 30 2021 5 min read story originally app...
# 97  company law firm names shown generated automat...
# 98  reuters illinois senate passed bill early wedn...
# 99  adds exelon comment sept 1 reuters illinois se...
#
# [100 rows x 5 columns]

# %%
# exploratory analysis with k-value for the k-means clustering:
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(DF['title'])

Sum_of_squared_distances = []
K = range(3,20)
for k in K:
   km = KMeans(n_clusters=k, max_iter=200, n_init=10)
   km = km.fit(X)
   Sum_of_squared_distances.append(km.inertia_)

plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
def Kmeans_clustering(DF, k, cluster_using = 'content'):
    # kmeans clustering using given k, 
    # cluster based on one-hot representation of the given feature cluster_using
    true_k = k
    model = KMeans(n_clusters = true_k, init = 'k-means++', max_iter = 200, n_init = 10)   
    X = TfidfVectorizer(stop_words = 'english').fit_transform(DF[cluster_using])
    model.fit(X)
    labels=model.labels_
    wiki_cl=pd.DataFrame(list(zip(DF['title'],labels)), columns=['title','cluster'])
    print(wiki_cl.sort_values(by=['cluster']))
    
    #
    result = {'cluster':labels,'wiki':DF['title']}
    result = pd.DataFrame(result)
    
    for k in range(0,true_k):
       s = result[result.cluster == k]
       text = s['wiki'].str.cat(sep = ' ')
       text = text.lower()
       text = ' '.join([word for word in text.split()])
       wordcloud = WordCloud(max_font_size = 50, max_words = 100, background_color = "white").generate(text)
       print('Cluster: {}'.format(k))
       print('Titles')
       titles = wiki_cl[wiki_cl.cluster == k]['title']         
       # print(titles.to_string(index=False))
       plt.figure()
       plt.imshow(wordcloud, interpolation = "bilinear")
       plt.axis("off")
       plt.show()

# %%
Kmeans_clustering(DF, 4, cluster_using = 'content')
# Out:
#                                                 title  cluster
# 17  world’s first cobalt free ev batteries finally...        0
# 1   hyundai motor group unveils hydrogen strategy ...        0
# 74  observer view pros cons deep sea mining observ...        0
# 79  explainer main battles ahead u democrats 3 5 t...        0
# 21  aren’t big bike firms tracking environmental i...        0
# ..                                                ...      ...
# 16      royal mail tests eeny weeny evs uk deliveries        3
# 15  electric vehicles usher new pennsylvania regul...        3
# 73  uae connects second barakah nuclear power unit...        3
# 56  factbox pros cons el salvador first bitcoin na...        3
# 66  japan mitsui partners exit mexico gas power pr...        3
#
# [100 rows x 2 columns]
# Cluster: 0
# Titles
# Cluster: 1
# Titles
# Cluster: 2
# Titles
# Cluster: 3
# Titles

# %%
Kmeans_clustering(DF, 7, cluster_using = 'content')
# Out:
#                                                 title  cluster
# 53  watchdog launch crackdown ads falsely claiming...        0
# 31  new york bans gas guzzler sales 2035 — states ...        0
# 16      royal mail tests eeny weeny evs uk deliveries        0
# 14       tesla tsla make inroads india nod 4 vehicles        0
# 99  update 1 illinois senate passes bill save nucl...        1
# ..                                                ...      ...
# 27  surge electric vehicle sales power lithium pri...        6
# 24  vitol plans electric hybrid bunker tankers sin...        6
# 26  fintech firm ideanomics buy via motors nearly ...        6
# 66  japan mitsui partners exit mexico gas power pr...        6
# 51  iveco charts future cnh nikola electric truck ...        6
#
# [100 rows x 2 columns]
# Cluster: 0
# Titles
# Cluster: 1
# Titles
# Cluster: 2
# Titles
# Cluster: 3
# Titles
# Cluster: 4
# Titles
# Cluster: 5
# Titles
# Cluster: 6
# Titles

# %%
Kmeans_clustering(DF, 10, cluster_using = 'content')
# Out:
#                                                 title  cluster
# 49  trudeau vows regulate oil gas emissions electr...        0
# 24  vitol plans electric hybrid bunker tankers sin...        0
# 40  startup keeps co2 air injecting ‘bio oil’ unde...        0
# 17  world’s first cobalt free ev batteries finally...        0
# 54  exclusive california bay area regulators probe...        0
# ..                                                ...      ...
# 2   electric vehicles produce substantial toxicity...        9
# 59             climate change india live without coal        9
# 74  observer view pros cons deep sea mining observ...        9
# 79  explainer main battles ahead u democrats 3 5 t...        9
# 56  factbox pros cons el salvador first bitcoin na...        9
#
# [100 rows x 2 columns]
# Cluster: 0
# Titles
# Cluster: 1
# Titles
# Cluster: 2
# Titles
# Cluster: 3
# Titles
# Cluster: 4
# Titles
# Cluster: 5
# Titles
# Cluster: 6
# Titles
# Cluster: 7
# Titles
# Cluster: 8
# Titles
# Cluster: 9
# Titles

# %%
def hier_clustering(DF):
    # Hierarchical clusteirng using AgglomerativeClustering
    model = AgglomerativeClustering()   
    X = TfidfVectorizer(stop_words = 'english').fit_transform(DF[cluster_using])
    model.fit(X)
    labels=model.labels_
    
    
    # up to here
    wiki_cl=pd.DataFrame(list(zip(DF['title'],labels)), columns=['title','cluster'])
    print(wiki_cl.sort_values(by=['cluster']))
    
    # Plot Dendrogram, reference link below
    # https://scikit-learn.org/stable/auto_examples/cluster/plot_agglomerative_dendrogram.html#sphx-glr-auto-examples-cluster-plot-agglomerative-dendrogram-py
    
    result = {'cluster':labels,'wiki':DF['title']}
    result = pd.DataFrame(result)
    
    for k in range(0,true_k):
       s = result[result.cluster == k]
       text = s['wiki'].str.cat(sep = ' ')
       text = text.lower()
       text = ' '.join([word for word in text.split()])
       wordcloud = WordCloud(max_font_size = 50, max_words = 100, background_color = "white").generate(text)
       print('Cluster: {}'.format(k))
       print('Titles')
       titles = wiki_cl[wiki_cl.cluster == k]['title']         
       # print(titles.to_string(index=False))
       plt.figure()
       plt.imshow(wordcloud, interpolation = "bilinear")
       plt.axis("off")
       plt.show()

# %%
def DBSCAN(DF, k)
